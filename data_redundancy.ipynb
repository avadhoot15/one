# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Dataset/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1       0.0       3                   Braund, Mr. Owen Harris
# 1              1       0.0       3                   Braund, Mr. Owen Harris
# 2              1       0.0       3                   Braund, Mr. Owen Harris
# 3              1       0.0       3                   Braund, Mr. Owen Harris
# 4              1       0.0       3                   Braund, Mr. Owen Harris
# ..           ...       ...     ...                                       ...
# 890          887       0.0       2                     Montvila, Rev. Juozas
# 891          888       1.0       1              Graham, Miss. Margaret Edith
# 892          889       0.0       3  Johnston, Miss. Catherine Helen "Carrie"
# 893          890       1.0       1                     Behr, Mr. Karl Howell
# 894          891       0.0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# # redundancy detection

# %%
df.duplicated().sum()
# Out:
# 4

# %% [markdown]
# # redundancy removal

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 5              2       NaN       1
# 6              3       NaN       3
# 7              4       NaN       1
# 8              5       0.0       3
# ..           ...       ...     ...
# 890          887       0.0       2
# 891          888       1.0       1
# 892          889       0.0       3
# 893          890       1.0       1
# 894          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 5    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                               Heikkinen, Miss. Laina  female   NaN      0
# 7         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
